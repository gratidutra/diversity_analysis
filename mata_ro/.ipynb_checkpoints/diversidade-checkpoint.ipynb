# %%
# install packages

install.packages('pacman')
install.packages('tidyverse')
install.packages('magrittr')
install.packages('lubridate')
install.packages('iNEXT')
install.packages('vegan')
install.packages('RAM')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘plyr’, ‘reshape2’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘permute’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘formatR’, ‘abind’, ‘lambda.r’, ‘futile.options’, ‘magic’, ‘lpSolve’, ‘linprog’, ‘RcppProgress’, ‘tmvnsim’, ‘gtools’, ‘caTools’, ‘Rtsne’, ‘png’, ‘rjson’, ‘jpeg’, ‘bitops’, ‘futile.logger’, ‘geometry’, ‘sp’, ‘pixmap’, ‘fastmatch’, ‘igraph’, ‘quadprog’, ‘maps’, ‘clusterGeneration’, ‘coda’, ‘combinat’, ‘expm’, ‘mnormt’, ‘numDeriv’, ‘plotrix’, ‘scatterplot3d’, ‘gplots’, ‘labdsv’, ‘gridExtra’, ‘ggmap’, ‘VennDiagram’, ‘FD’, ‘RgoogleMaps’, ‘reshape’, ‘ade4’, ‘phangorn’, ‘phytools’, ‘ape’

# %%
# chamando as libs necessárias

pacman::p_load(tidyverse, magrittr, lubridate, iNEXT, vegan, RAM)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
#
# iNEXT installed
# also installing the dependencies ‘abind’, ‘lambda.r’, ‘futile.options’, ‘magic’, ‘lpSolve’, ‘linprog’, ‘RcppProgress’, ‘tmvnsim’, ‘gtools’, ‘caTools’, ‘Rtsne’, ‘png’, ‘rjson’, ‘bitops’, ‘futile.logger’, ‘geometry’, ‘sp’, ‘pixmap’, ‘fastmatch’, ‘igraph’, ‘quadprog’, ‘Rcpp’, ‘clusterGeneration’, ‘coda’, ‘combinat’, ‘expm’, ‘mnormt’, ‘plotrix’, ‘gplots’, ‘labdsv’, ‘gridExtra’, ‘ggmap’, ‘VennDiagram’, ‘FD’, ‘RgoogleMaps’, ‘reshape’, ‘ade4’, ‘phangorn’, ‘phytools’

# %%
# lendo o arquivo de entrada

df <- read_csv("data.csv")
# Out:
# Rows: 540 Columns: 14
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (9): Espécie, Localidade, Latitude, Longitude, Ambiente, Mês, Armadilha...
# dbl  (2): Temperatura (°C), Umidade (%)
# lgl  (1): Sexo
# date (1): Data da captura
# time (1): Hora de captura
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# Diagrama de Venn

count <- df %>% 
  group_by(`Espécie`, Localidade) %>%
  summarise(total = n())

p1 <- count %>%
  filter(Localidade == 'P1 - Argeu') %>%
  select(Localidade, `Espécie`)


p5 <- count %>%
  filter(Localidade == 'P5-Neucivaldo') %>%
  select(Localidade, `Espécie`)


group.venn(list(Argeu=p1$Espécie, Neucivaldo=p5$Espécie), label=FALSE, 
           fill = c("lightpink", "lightblue"),
           cat.pos = c(0, 0),
           cex = 1.8)
# Out:
# `summarise()` has grouped output by 'Espécie'. You can override using the `.groups` argument.
# plot without title

# %%
# top 5 specie

top_specie <- df %>% group_by(Espécie) %>%
  summarise(total = n()) %>%
  arrange(-total) %>% slice(1:5)   

top_specie
# Out:
#   Espécie              total
# 1 Tabanus antarcticus  142
# 2 Stypommisa aripuana   76
# 3 Pityocera cervus      54
# 4 Tabanus occidentalis  39
# 5 Tabaus antarcticus    39

# %%
# Coletas por mês

collect_by_month <- df %>% group_by(Mês, Espécie) %>%
summarise(total = n()) %>%
arrange(-total) %>%  filter(total >= 12)

ggplot(collect_by_month, aes(Mês, total, fill = total)) +
  geom_bar(binwidth = 1, stat = "identity") +
  theme_light() +
  scale_fill_gradient(low = "lightblue", high = "blue") +
  facet_wrap(~Espécie) +
  ylab("Abundance") +
  xlab("Month") +
  theme(axis.text.x = element_text(angle = 45, vjust = 1, hjust = 1)) +
  coord_polar()
# Out:
# `summarise()` has grouped output by 'Mês'. You can override using the `.groups` argument.
#
# Warning message:
# “Ignoring unknown parameters: binwidth”
# plot without title

# %%
# Coletas por hora

collect_by_hour <- df %>% group_by(hour = hour(`Hora de captura`), Espécie) %>%
summarise(total = n()) %>%
arrange(-total) %>% filter(total > 10)

ggplot(collect_by_hour, aes(hour, total, fill = total)) +
  geom_bar(binwidth = 1, stat = "identity") +
  theme_light() +
  scale_fill_gradient(low = "lightblue", high = "blue") +
  scale_x_continuous(breaks = seq(5, 17, by = 2)) +
  facet_wrap(~Espécie) +
  ylab("Abundance") +
  xlab("Hour") +
  theme(axis.text.x = element_text(angle = 45, vjust = 1, hjust = 1)) +
  coord_polar()
# Out:
# `summarise()` has grouped output by 'hour'. You can override using the `.groups` argument.
#
# Warning message:
# “Ignoring unknown parameters: binwidth”
# plot without title

# %%
# Coletas por hora - região do cavalo

collect_by_horse <- df %>% group_by(hour = hour(`Hora de captura`), `Local de pouso`) %>%
summarise(total = n()) %>%
arrange(-total) %>% filter(total >= 8)

ggplot(collect_by_horse, aes(as.factor(hour), total, fill = total)) +
  geom_bar(binwidth = 1, stat = "identity") +
  theme_light() +
  scale_fill_gradient(low = "lightblue", high = "blue") +
  facet_wrap(~`Local de pouso`) +
  ylab("Abundance") +
  xlab("Hour") +
  theme(axis.text.x = element_text(angle = 45, vjust = 1, hjust = 1))
# Out:
# `summarise()` has grouped output by 'hour'. You can override using the `.groups` argument.
#
# Warning message:
# “Ignoring unknown parameters: binwidth”
# plot without title

# %%
# NMDS

rich <- df  %>%  group_by(Localidade, Mês) %>%
summarise(rich = n_distinct(Espécie))

data_nmds <- df %>%
group_by(Espécie, Localidade, Mês) %>%
summarise(abund = n()) %>%
pivot_wider(names_from = Espécie, values_from = abund) %>%
mutate(
  across(everything(), ~ replace_na(.x, 0))
) %>% left_join(rich, by = c("Localidade", "Mês"))


run_nmds <- data_nmds

run_nmds$Localidade <- NULL
run_nmds$Mês <- NULL
run_nmds$rich <- NULL

nmds <- metaMDS(run_nmds)

scores(nmds)  %>%
as_tibble() %>%
cbind(data_nmds) %>%
as_tibble()%>%
ggplot(aes(x = NMDS1, y = NMDS2)) +
  geom_point(aes(size = rich, color = Mês)) +
  stat_ellipse(geom = "polygon", aes(group = Mês, color = Mês, fill = Mês), alpha = 0.3) +
  annotate("text", x = -2, y = 0.95, label = paste0("stress: ", format(nmds$stress, digits = 4)), hjust = 0) +
  theme_bw()
# Out:
# `summarise()` has grouped output by 'Localidade'. You can override using the `.groups` argument.
#
# `summarise()` has grouped output by 'Espécie', 'Localidade'. You can override using the `.groups` argument.
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.03396049
# Run 1 stress 0.0339605
# ... Procrustes: rmse 0.0002897416  max resid 0.000504092
# ... Similar to previous best
# Run 2 stress 0.03396054
# ... Procrustes: rmse 0.0003280756  max resid 0.0005673904
# ... Similar to previous best
# Run 3 stress 0.07282582
# Run 4 stress 0.07282575
# Run 5 stress 0.03396055
# ... Procrustes: rmse 0.0001078168  max resid 0.0001818784
# ... Similar to previous best
# Run 6 stress 0.03396052
# ... Procrustes: rmse 8.671764e-05  max resid 0.0001706321
# ... Similar to previous best
# Run 7 stress 0.08629289
# Run 8 stress 0.03396047
# ... New best solution
# ... Procrustes: rmse 0.0002352633  max resid 0.000396831
# ... Similar to previous best
# Run 9 stress 0.0339605
# ... Procrustes: rmse 0.0001152137  max resid 0.0002265495
# ... Similar to previous best
# Run 10 stress 0.07282579
# Run 11 stress 0.03396059
# ... Procrustes: rmse 0.0003191476  max resid 0.0005644234
# ... Similar to previous best
# Run 12 stress 0.07282567
# Run 13 stress 0.03396047
# ... New best solution
# ... Procrustes: rmse 0.0001050155  max resid 0.0002221286
# ... Similar to previous best
# Run 14 stress 0.0339605
# ... Procrustes: rmse 3.996353e-05  max resid 6.862685e-05
# ... Similar to previous best
# Run 15 stress 0.03396045
# ... New best solution
# ... Procrustes: rmse 0.0001616519  max resid 0.0002634474
# ... Similar to previous best
# Run 16 stress 0.03396044
# ... New best solution
# ... Procrustes: rmse 1.484238e-05  max resid 2.616723e-05
# ... Similar to previous best
# Run 17 stress 0.03396059
# ... Procrustes: rmse 0.00019153  max resid 0.0003114071
# ... Similar to previous best
# Run 18 stress 0.03396056
# ... Procrustes: rmse 0.0001771965  max resid 0.0002885188
# ... Similar to previous best
# Run 19 stress 0.07282587
# Run 20 stress 0.03396045
# ... Procrustes: rmse 0.0001100432  max resid 0.0001792633
# ... Similar to previous best
# *** Solution reached
# Too few points to calculate an ellipse
#
# Too few points to calculate an ellipse
#
# Too few points to calculate an ellipse
#
# Too few points to calculate an ellipse
#
# Too few points to calculate an ellipse
# plot without title

# %%
# Rich x Abund
rich_abund <- data_nmds %>% 
  pivot_longer(!c(Localidade, Mês, rich), names_to = "Espécie", values_to = "abund") %>% 
  filter(Espécie %in% c("Tabanus antarcticus","Stypommisa aripuana",
                      "Pityocera cervus", "Tabanus occidentalis", 
                      "Tabaus antarcticus"))

ggplot(rich_abund, aes(x = rich, y = abund)) +
  geom_point() +
  geom_smooth(method = "lm", alpha = .15) +
  facet_wrap(~Espécie)


# Temperatura e umidade

df_climatics <- df %>% group_by(Mês) %>%
summarise(
  total = n(),
  temp = mean(`Temperatura (°C)`),
  um = mean(`Umidade (%)`)
)

ggplot(df_climatics, aes(x = temp, y = total)) +
  geom_point() +
  geom_smooth(method = "lm", alpha = .15)

ggplot(df_climatics, aes(x = um, y = total)) +
  geom_point() +
  geom_smooth(method = "lm", alpha = .15)

ggplot(df_climatics, aes(Mês, temp)) +
  geom_bar(stat = "identity", fill = "steelblue") +
  theme_light()
# Out:
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'
# plot without title
# `geom_smooth()` using formula 'y ~ x'
# plot without title
# plot without title
# plot without title

# %%
# Diversidade

abund <- df %>%
group_by(Espécie, Localidade) %>%
summarise(total = n()) %>%
pivot_wider(names_from = Localidade, values_from = total)  %>%
replace_na(list(`P1 - Argeu` = 0, `P5-Neucivaldo` = 0)) %>%
column_to_rownames(var = "Espécie")

resultados_tabanidae <- iNEXT(abund,
  q = 0,
  datatype = "abundance",
  endpoint = 800
)

abund
# Out:
# `summarise()` has grouped output by 'Espécie'. You can override using the `.groups` argument.
#                                          P1 - Argeu P5-Neucivaldo
# Acanthocera fairchildi                    5          0
# Catachlorops difficilis                   5          0
# Catachlorops halteratus                   1          0
# Chrysops varians                          1          1
# Chrysops variegatus                       4          4
# Diachlorus curvipes                       1          0
# Dichelacera cervicornis                   0          2
# Dichelacera tetradelta                   12          1
# Leucotabanus albovarius                   2          0
# Leucotabanus exaestuans                   4          3
# Leucotabanus pauculus                     1          0
# Phaeotabanus nigriflavus                  1          0
# Philipotabanus pictus                     0          2
# Pityocera cervus                         43         11
# Pityocera pernaquila                      0         13
# Poeciloderas quadripunctatus              1          0
# Stenotabanus albilinearis                 2         12
# Stenotabanus incipiens                    8          0
# Stypommisa apicalis                       4          0
# Stypommisa aripuana                      66         10
# Stypommisa captiroptera                   1          0
# Stypommisa modica                         2          1
# Tabanus ?fuscofasciatus                   2          0
# Tabanus antarcticus                      72         70
# Tabanus discifer                          0          1
# Tabanus discus                            4          0
# Tabanus dorsorufus                        1          0
# Tabanus humboldti                         0          1
# Tabanus macquarti                         1          0
# Tabanus mucronatus                        4         10
# Tabanus nebulosus                         1          0
# Tabanus occidentalis                     16         23
# Tabanus occidentalis var. ?dorsovittatus  0          1
# Tabanus occidentalis var. dorsovittatus   7          4
# Tabanus occidentalis var. modestus       19         11
# Tabanus occidentalis var.modestus         2          0
# Tabanus occiedntalis                      1          0
# Tabanus piceiventris                      0          2
# Tabanus pungens                           0          1
# Tabanus restrepoensis                     1          0
# Tabanus rondoniensis sp.n.                1          0
# Tabanus rubripes                          8          9
# Tabanus rupripes                          1          0
# Tabanus sorbillans                        0          1
# Tabanus trivittatus                       1          0
# Tabaus antarcticus                        5         34
# Tabaus occidentalis var. modestus         0          1

# %%
## Resultado
resultados_tabanidae$AsyEst

ggiNEXT(resultados_tabanidae, type = 1) + theme_light()
# Out:
#   Site          Diversity         Observed Estimator s.e.   LCL    UCL
# 1 P1 - Argeu    Species richness  37.000   59.428    16.036 43.365 116.026
# 2 P1 - Argeu    Shannon diversity 13.227   14.623     1.210 13.227  16.995
# 3 P1 - Argeu    Simpson diversity  7.727    7.899     0.584  7.727   9.043
# 4 P5-Neucivaldo Species richness  25.000   38.441    12.408 27.885  87.618
# 5 P5-Neucivaldo Shannon diversity 11.268   12.292     1.001 11.268  14.253
# 6 P5-Neucivaldo Simpson diversity  7.008    7.198     0.788  7.008   8.743
# plot without title
